# %% [markdown]
# Since the original data was compiled into a tarfile, to access it within Jupyter Notebook, we had to first import the tarfile library in Python so that we could read and write with tar archive files. Then, we opened our dataset from the Yelp Database and extracted all the files. After, we closed the tar file.

# %%
import tarfile
file = tarfile.open('yelp_dataset.tar')
file.extractall('./project_files')
file.close()

# %% [markdown]
# To start doing some cleaning on our chosen data, we first imported the json, pandas, and numpy library. We also loaded the sql extension.

# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %% [markdown]
# Here, we opened the Yelp Academic Dataset Business Json file and read it. We then converted the file into a CSV file so that we could more easily manipulate and clean the data.

# %%
with open('./project_files/yelp_academic_dataset_business.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile, lines=True)
df.to_csv('./project_files/yelp_academic_dataset_business.csv', encoding='utf-8', index = False)

# %% [markdown]
# After converting the data, we used the pandas library to read the csv file and set it equal to a data frame we called data.

# %%
After converting the data, we used the pandas library to read the csv file and set it equal to a data frame we called data.

# %% [markdown]
# First, we wanted to extract all the businesses that were categorized as restaurants, so we looked at the categories column in our data frame and picked out businesses where the content in their category descriptions included the word "Restaurants" in them. We then displayed that data to check whether this piece of code worked.

# %%
data = pd.read_csv('./project_files/yelp_academic_dataset_business.csv')
data
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2                  5255 E Broadway Blvd         Tucson    AZ       85711
# 3                           935 Race St   Philadelphia    PA       19107
# 4                         101 Walnut St     Green Lane    PA       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    AB     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    TN       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    IN       46250
# 150344                     2472 Troy Rd   Edwardsville    IL       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    FL       33572
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       34.426679 -119.711197    5.0             7        0
# 1       38.551126  -90.335695    3.0            15        1
# 2       32.223236 -110.880452    3.5            22        0
# 3       39.955505  -75.155564    4.0            80        1
# 4       40.338183  -75.471659    4.5            13        1
# ...           ...         ...    ...           ...      ...
# 150341  53.468419 -113.492054    3.0            13        1
# 150342  36.115118  -86.766925    4.0             5        1
# 150343  39.908707  -86.065088    3.5             8        1
# 150344  38.782351  -89.950558    4.0            24        1
# 150345  27.771002  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 1                  {'BusinessAcceptsCreditCards': 'True'}
# 2       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...                                                   ...
# 150341  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344  {'BusinessParking': "{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                     NaN
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 150343                                                NaN
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [150346 rows x 14 columns]

# %% [markdown]
# Here, we are narrowing down our data even more by selecting the restaurant businesses that were given from the previous cell and filtering them down even more to only include restaurants that were located in a certain area. In this case, we looked at restaurants in the Nashville, TN area. Our goal with this was to analyze restaurants on 2nd Ave which is known to be a historic tourist destination, so we had to first find the broader category of Nashville restaurants so that we can compare restaurants that aren't on 2nd Ave in Nashville with those that are.

# %%
data = data.dropna()
data = data[data["categories"].str.contains('Restaurants')]
data
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 12      il_Ro8jwPlHresjw9EGmBg                        Denny's
# 14      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# ...                        ...                            ...
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 150340  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                       address             city state postal_code   latitude  \
# 3                 935 Race St     Philadelphia    PA       19107  39.955505
# 5               615 S Main St     Ashland City    TN       37015  36.269593
# 9         2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 12               8901 US 31 S     Indianapolis    IN       46227  39.637133
# 14              2575 E Bay Dr            Largo    FL       33771  27.916116
# ...                       ...              ...   ...         ...        ...
# 150325        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339        4405 Pennell Rd            Aston    DE       19014  39.856185
# 150340  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0            80        1
# 5       -87.058943    2.0             6        1
# 9       -86.768170    1.5            10        1
# 12      -86.127217    2.5            28        1
# 14      -82.760461    4.5           100        0
# ...            ...    ...           ...      ...
# 150325  -75.310344    3.0            11        1
# 150327 -116.284689    4.0            33        1
# 150336  -75.158665    4.5            35        1
# 150339  -75.427725    4.5            14        1
# 150340 -113.675999    4.5            18        0
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 9       {'RestaurantsAttire': "'casual'", 'Restaurants...
# 12      {'RestaurantsReservations': 'False', 'Restaura...
# 14      {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# ...                                                   ...
# 150325  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 150327  {'WiFi': "'free'", 'RestaurantsGoodForGroups':...
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...
# 150339  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 150340  {'Ambience': "{'touristy': False, 'hipster': F...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 12      American (Traditional), Restaurants, Diners, B...
# 14            Food, Delis, Italian, Bakeries, Restaurants
# ...                                                   ...
# 150325  Restaurants, Sandwiches, Convenience Stores, C...
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 150336                               Restaurants, Mexican
# 150339  Restaurants, Comfort Food, Food, Food Trucks, ...
# 150340                        Middle Eastern, Restaurants
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 12      {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...
# 14      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# ...                                                   ...
# 150325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150327  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150339  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150340  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [44470 rows x 14 columns]

# %% [markdown]
# Here, we are narrowing down our data even more by selecting the restaurant businesses that were given from the previous cell and filtering them down even more to only include restaurants that were located in a certain area. In this case, we looked at restaurants in the Nashville, TN area. Our goal with this was to analyze restaurants on 2nd Ave which is known to be a historic tourist destination, so we had to first find the broader category of Nashville restaurants so that we can compare restaurants that aren't on 2nd Ave in Nashville with those that are.

# %%
postal = data[data["postal_code"].str.contains("37201")]
print(len(postal))
postal
# Out:
# 115
#                    business_id                            name  \
# 27      tMkwHmWFUEXrC9ZduonpTg              The Green Pheasant
# 89      oaboaRBUgGjbo2kfUIKDLQ                Mike's Ice Cream
# 159     X_E7U2lVNEwbH_gpOBmAHQ                  Cerveza Jack's
# 798     Gki1ureeRKqlIkQ-AELDVg                         Brugada
# 1044    RJPRi1pwocHNZr9ISz_P-A            National Underground
# ...                        ...                             ...
# 145129  0uL-FXY1M2UC12eZcFlTuQ  The Hampton Social - Nashville
# 145577  hojhzuA9hiTHk_NtdaWWpw           Mediterranean Cuisine
# 148131  NfOnxD8NT4UQmSfBY6iqng                The George Jones
# 148956  nygJ4mY0glpdWGv_Hmp6Dg                Joe's Crab Shack
# 150322  2MAQeAqmD8enCT2ZYqUgIQ     The Melting Pot - Nashville
#
#                      address       city state postal_code   latitude  \
# 27             215 1st Ave S  Nashville    TN       37201  36.159886
# 89             129 2nd Ave N  Nashville    TN       37201  36.162649
# 159            135 2nd Ave N  Nashville    TN       37201  36.162799
# 798          204 Commerce St  Nashville    TN       37201  36.163323
# 1044            105 Broadway  Nashville    TN       37201  36.161795
# ...                      ...        ...   ...         ...        ...
# 145129         201 1st Ave S  Nashville    TN       37201  36.159959
# 145577       204 Commerce St  Nashville    TN       37201  36.163289
# 148131         128 2nd Ave N  Nashville    TN       37201  36.162983
# 148956         123 2nd Ave S  Nashville    TN       37201  36.160947
# 150322  166 2nd Ave N, Ste A  Nashville    TN       37201  36.163875
#
#         longitude  stars  review_count  is_open  \
# 27     -86.773197    4.0           161        0
# 89     -86.775973    4.5           593        1
# 159    -86.776016    4.0           182        1
# 798    -86.776592    3.5            49        1
# 1044   -86.774466    2.5           126        0
# ...           ...    ...           ...      ...
# 145129 -86.773254    4.5           608        1
# 145577 -86.776467    3.5            19        0
# 148131 -86.775375    3.5           316        0
# 148956 -86.774865    3.0           192        1
# 150322 -86.776311    4.0           204        0
#
#                                                attributes  \
# 27      {'RestaurantsGoodForGroups': 'True', 'HappyHou...
# 89      {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 159     {'GoodForDancing': 'True', 'Smoking': "u'no'",...
# 798     {'NoiseLevel': "'average'", 'Caters': 'False',...
# 1044    {'RestaurantsGoodForGroups': 'True', 'WiFi': "...
# ...                                                   ...
# 145129  {'CoatCheck': 'False', 'RestaurantsReservation...
# 145577  {'RestaurantsDelivery': 'False', 'RestaurantsR...
# 148131  {'BusinessParking': "{'garage': True, 'street'...
# 148956  {'OutdoorSeating': 'True', 'BYOBCorkage': "'no...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
#
#                                                categories  \
# 27                         Restaurants, Japanese, Seafood
# 89      Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# 159                 Nightlife, Restaurants, Bars, Mexican
# 798     Restaurants, Nightlife, Dance Clubs, Falafel, ...
# 1044    Music Venues, American (New), Restaurants, Nig...
# ...                                                   ...
# 145129  American (New), Cocktail Bars, American (Tradi...
# 145577  Greek, Mediterranean, Restaurants, Middle Eastern
# 148131  Restaurants, Arts & Entertainment, Bars, Night...
# 148956  American (Traditional), Seafood, Gluten-Free, ...
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
#
#                                                     hours
# 27      {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...
# 89      {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
# 159     {'Monday': '0:0-0:0', 'Wednesday': '11:0-22:0'...
# 798     {'Monday': '17:0-2:30', 'Tuesday': '17:0-2:30'...
# 1044    {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# ...                                                   ...
# 145129  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 145577  {'Monday': '11:0-21:30', 'Tuesday': '11:0-21:3...
# 148131  {'Monday': '0:0-0:0', 'Thursday': '11:0-22:0',...
# 148956  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
#
# [115 rows x 14 columns]

# %% [markdown]
# Here, we are narrowing down our restaurant data in Nashville to include only those restaurants where the address contains the fact that the restaurants are on 2nd Ave. To compare the number of restaurants that fit this category and the one in the cell above, we printed out the length of this data frame and then displayed the data frame.

# %%
# data["address"] = data["adress"].astype(str)
two_ave = postal[postal["address"].str.contains("2nd Ave")]
print(len(two_ave))
two_ave
# Out:
# 31
#                    business_id                                     name  \
# 89      oaboaRBUgGjbo2kfUIKDLQ                         Mike's Ice Cream
# 159     X_E7U2lVNEwbH_gpOBmAHQ                           Cerveza Jack's
# 1494    8s1uT8dyBEUwTNeHoZntMg                                   El Rey
# 4689    QUxFneps0qX5S8XpEUnazg                    Piranha's Bar & Grill
# 7710    xB2NmS0JG1Vgy7dK2ftcwQ                        Taco Bell Cantina
# 17517   maOMGu_2dSHKydBgZdTsvQ                         Wildhorse Saloon
# 26266   xlMQBBt9wrtahdqiRDcVSg                             The Stillery
# 27061   LF8UjsBRaQ4Aqwu3ARxnBg   Rodizio Grill The Brazilian Steakhouse
# 40375   DaQ6YSXmoXQH1qYXNSR1hA                                  Hooters
# 55579   E8nFvonCaW63W9d3zUYhgQ                              Bebo's Cafe
# 58366   JWUkEIayb3F8la3TWe-eyw                                Stockyard
# 71945   UlrEGYuRd5pxW0n4iCR9CQ                             Chicken Guy!
# 78237   VuubVgCDC4rbvF_iPIhh1A                                 Bartella
# 81389   cxQ3CKel3EEZLYEyu9v3og                 Choices Restaurant & Bar
# 83703   NXaw6ox4vQkLfQ13sq_oGg                    Porch Coffee & Market
# 85574   ZDY-jvetOMOE5BMM8e_BcQ           Dick's Last Resort - Nashville
# 87435   Dp6QT6_evsKemZNKgtJ7nA            REPUBLIC quality food & drink
# 91769   WrgdQF8kzvONbZctSPlF4A                                  Ichiban
# 92564   um2W1Gi4-zR7e17t5pZ_Pg                   Nashville Street Tacos
# 98446   RMt9p9efzYfV_cHwXLB-CA                            Gray & Dudley
# 107768  2VczMMo9tWBNPBEHMnoP5w                      Buffalo's Nashville
# 109109  9TvJuG22ZyCXJVYzDaDNxw                                 Pita Pit
# 111448  vpQWbT7ZKcHMVKxEVR8Cuw                    Benchmark Bar & Grill
# 114525  Tdp95AviUqzvUd3H2C5xvw                         Famous Nashville
# 125972  py2JAvs-JwqMgllQ7YtP8A  The Murder Mystery Company in Nashville
# 130647  qnOffBt8iV6umLvDZ5PNDw                       Music City Chicken
# 136447  k7o9D7XQ0eGuz3nmKB1wXg         McFadden's Restaurant and Saloon
# 141909  1KpNlu8VM8ukw3uOzmMFPA                     BB King's Blues Club
# 148131  NfOnxD8NT4UQmSfBY6iqng                         The George Jones
# 148956  nygJ4mY0glpdWGv_Hmp6Dg                         Joe's Crab Shack
# 150322  2MAQeAqmD8enCT2ZYqUgIQ              The Melting Pot - Nashville
#
#                      address       city state postal_code   latitude  \
# 89             129 2nd Ave N  Nashville    TN       37201  36.162649
# 159            135 2nd Ave N  Nashville    TN       37201  36.162799
# 1494           139 2nd Ave N  Nashville    TN       37201  36.162919
# 4689           113 2nd Ave N  Nashville    TN       37201  36.162251
# 7710           131 2nd Ave N  Nashville    TN       37201  36.162724
# 17517          120 2nd Ave N  Nashville    TN       37201  36.162766
# 26266          113 2nd Ave N  Nashville    TN       37201  36.162249
# 27061   166 2nd Ave N, Ste C  Nashville    TN       37201  36.164010
# 40375          184 2nd Ave N  Nashville    TN       37201  36.164572
# 55579          135 2nd Ave N  Nashville    TN       37201  36.162812
# 58366          901 2nd Ave N  Nashville    TN       37201  36.157588
# 71945          139 2nd Ave N  Nashville    TN       37201  36.162919
# 78237          164 2nd Ave N  Nashville    TN       37201  36.163949
# 81389          128 2nd Ave N  Nashville    TN       37201  36.163090
# 83703          401 2nd Ave S  Nashville    TN       37201  36.157509
# 85574          154 2nd Ave N  Nashville    TN       37201  36.163671
# 87435          109 2nd Ave N  Nashville    TN       37201  36.162162
# 91769          109 2nd Ave N  Nashville    TN       37201  36.162124
# 92564          129 2nd Ave N  Nashville    TN       37201  36.162625
# 98446          221 2nd Ave N  Nashville    TN       37201  36.165252
# 107768         154 2nd Ave N  Nashville    TN       37201  36.163671
# 109109         121 2nd Ave N  Nashville    TN       37201  36.162500
# 111448         117 2nd Ave N  Nashville    TN       37201  36.162408
# 114525         110 2nd Ave N  Nashville    TN       37201  36.162290
# 125972         160 2nd Ave N  Nashville    TN       37201  36.163869
# 130647         109 2nd Ave N  Nashville    TN       37201  36.162162
# 136447         134 2nd Ave N  Nashville    TN       37201  36.163155
# 141909         152 2nd Ave N  Nashville    TN       37201  36.163424
# 148131         128 2nd Ave N  Nashville    TN       37201  36.162983
# 148956         123 2nd Ave S  Nashville    TN       37201  36.160947
# 150322  166 2nd Ave N, Ste A  Nashville    TN       37201  36.163875
#
#         longitude  stars  review_count  is_open  \
# 89     -86.775973    4.5           593        1
# 159    -86.776016    4.0           182        1
# 1494   -86.776160    3.0            89        0
# 4689   -86.775710    4.0            75        0
# 7710   -86.776014    2.5            26        1
# 17517  -86.775178    3.5           559        1
# 26266  -86.775712    4.5          2588        1
# 27061  -86.776030    4.0           510        1
# 40375  -86.776655    2.0           115        0
# 55579  -86.776075    2.0            12        0
# 58366  -86.780780    2.5           122        0
# 71945  -86.776068    3.0            24        1
# 78237  -86.775981    4.5            12        0
# 81389  -86.775096    2.5            13        0
# 83703  -86.772627    4.5            14        1
# 85574  -86.775767    3.0           153        1
# 87435  -86.775591    4.0            16        1
# 91769  -86.775627    4.0           144        0
# 92564  -86.775847    3.5           103        0
# 98446  -86.777809    4.0           181        1
# 107768 -86.775767    3.5            63        1
# 109109 -86.775760    3.0            79        0
# 111448 -86.775813    4.0           109        1
# 114525 -86.775283    3.5           109        1
# 125972 -86.775873    1.5             8        1
# 130647 -86.775591    4.5           132        0
# 136447 -86.775456    2.0            46        0
# 141909 -86.776030    3.5           583        1
# 148131 -86.775375    3.5           316        0
# 148956 -86.774865    3.0           192        1
# 150322 -86.776311    4.0           204        0
#
#                                                attributes  \
# 89      {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 159     {'GoodForDancing': 'True', 'Smoking': "u'no'",...
# 1494    {'RestaurantsReservations': 'False', 'Restaura...
# 4689    {'OutdoorSeating': 'False', 'RestaurantsReserv...
# 7710                      {'RestaurantsDelivery': 'True'}
# 17517   {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 26266   {'BikeParking': 'True', 'CoatCheck': 'False', ...
# 27061   {'BikeParking': 'False', 'RestaurantsAttire': ...
# 40375   {'RestaurantsAttire': "u'casual'", 'HasTV': 'T...
# 55579   {'Ambience': "{'romantic': False, 'intimate': ...
# 58366   {'BYOB': 'False', 'GoodForKids': 'False', 'Goo...
# 71945   {'OutdoorSeating': 'True', 'Caters': 'True', '...
# 78237   {'Corkage': 'False', 'RestaurantsTableService'...
# 81389   {'HappyHour': 'True', 'WheelchairAccessible': ...
# 83703   {'OutdoorSeating': 'True', 'RestaurantsTableSe...
# 85574   {'GoodForKids': 'False', 'RestaurantsGoodForGr...
# 87435   {'WheelchairAccessible': 'True', 'RestaurantsR...
# 91769   {'NoiseLevel': "u'quiet'", 'OutdoorSeating': '...
# 92564   {'Ambience': "{'romantic': False, 'intimate': ...
# 98446   {'RestaurantsTableService': 'True', 'Restauran...
# 107768  {'Alcohol': "'full_bar'", 'BikeParking': 'True...
# 109109  {'WiFi': "'no'", 'OutdoorSeating': 'False', 'R...
# 111448  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 114525  {'BestNights': "{'monday': False, 'tuesday': F...
# 125972  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 130647  {'RestaurantsReservations': 'False', 'OutdoorS...
# 136447  {'Alcohol': "u'full_bar'", 'OutdoorSeating': '...
# 141909  {'RestaurantsTakeOut': 'True', 'Caters': 'True...
# 148131  {'BusinessParking': "{'garage': True, 'street'...
# 148956  {'OutdoorSeating': 'True', 'BYOBCorkage': "'no...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
#
#                                                categories  \
# 89      Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# 159                 Nightlife, Restaurants, Bars, Mexican
# 1494                                 Restaurants, Mexican
# 4689    Restaurants, Dive Bars, Sports Bars, Bars, Nig...
# 7710    Arts & Entertainment, Music Venues, Fast Food,...
# 17517   Tours, Local Flavor, Hotels & Travel, Arts & E...
# 26266   American (New), Restaurants, Pubs, Beer, Wine ...
# 27061    Gluten-Free, Brazilian, Restaurants, Steakhouses
# 40375   American (Traditional), Chicken Wings, Bars, N...
# 55579   Cafes, Restaurants, Nightlife, Bars, Hookah Ba...
# 58366            Steakhouses, Restaurants, Food, Desserts
# 71945    Restaurants, Chicken Shop, Fast Food, Sandwiches
# 78237   Desserts, French, Breakfast & Brunch, Restaura...
# 81389   Bars, Nightlife, American (Traditional), South...
# 83703   Convenience Stores, Food, Beer, Wine & Spirits...
# 85574   American (Traditional), Restaurants, Nightlife...
# 87435                             Gastropubs, Restaurants
# 91769                   Sushi Bars, Japanese, Restaurants
# 92564                          Restaurants, Mexican, Food
# 98446               American (New), Restaurants, Southern
# 107768  Bars, Nightlife, Sports Bars, Beer, Wine & Spi...
# 109109  Fast Food, Restaurants, Event Planning & Servi...
# 111448  American (New), Restaurants, Bars, Arts & Ente...
# 114525  Music Venues, Lounges, American (Traditional),...
# 125972  Event Planning & Services, Restaurants, Food, ...
# 130647  Restaurants, Food, Sandwiches, Beer, Wine & Sp...
# 136447  Burgers, Pubs, Nightlife, Restaurants, Bars, I...
# 141909  Music Venues, American (Traditional), Wine Bar...
# 148131  Restaurants, Arts & Entertainment, Bars, Night...
# 148956  American (Traditional), Seafood, Gluten-Free, ...
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
#
#                                                     hours
# 89      {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
# 159     {'Monday': '0:0-0:0', 'Wednesday': '11:0-22:0'...
# 1494    {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 4689    {'Monday': '11:0-3:0', 'Tuesday': '11:0-3:0', ...
# 7710    {'Monday': '10:0-1:45', 'Tuesday': '10:0-1:45'...
# 17517   {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...
# 26266   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 27061   {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:30',...
# 40375   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 55579   {'Monday': '17:0-3:0', 'Tuesday': '17:0-3:0', ...
# 58366   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 71945   {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 78237   {'Tuesday': '10:0-21:0', 'Wednesday': '10:0-21...
# 81389   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 83703   {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
# 85574   {'Monday': '12:0-20:0', 'Tuesday': '12:0-20:0'...
# 87435   {'Monday': '16:0-0:0', 'Tuesday': '16:0-0:0', ...
# 91769   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 92564   {'Monday': '11:0-21:0', 'Tuesday': '11:0-23:0'...
# 98446   {'Monday': '0:0-0:0', 'Wednesday': '15:0-22:45...
# 107768  {'Monday': '12:0-23:0', 'Tuesday': '12:0-23:0'...
# 109109  {'Monday': '10:0-2:0', 'Tuesday': '10:0-2:0', ...
# 111448  {'Monday': '15:0-23:0', 'Tuesday': '15:0-23:0'...
# 114525  {'Wednesday': '11:0-22:0', 'Thursday': '11:0-2...
# 125972  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
# 130647  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 136447  {'Monday': '11:0-3:0', 'Tuesday': '11:0-3:0', ...
# 141909  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 148131  {'Monday': '0:0-0:0', 'Thursday': '11:0-22:0',...
# 148956  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...

# %% [markdown]
# Here, we are checking whether the restaurants on 2nd Ave are still open or not by using the binary column "is_open" that is given in the data. We then selected all the restaurants on 2nd Ave that are closed and created a new data frame with this data. We again printed the length of the new data frame and displayed the contents.

# %%
is_closed = two_ave[two_ave["is_open"] == 0]
print(len(is_closed))
is_closed
# Out:
# 14
#                    business_id                              name  \
# 1494    8s1uT8dyBEUwTNeHoZntMg                            El Rey
# 4689    QUxFneps0qX5S8XpEUnazg             Piranha's Bar & Grill
# 40375   DaQ6YSXmoXQH1qYXNSR1hA                           Hooters
# 55579   E8nFvonCaW63W9d3zUYhgQ                       Bebo's Cafe
# 58366   JWUkEIayb3F8la3TWe-eyw                         Stockyard
# 78237   VuubVgCDC4rbvF_iPIhh1A                          Bartella
# 81389   cxQ3CKel3EEZLYEyu9v3og          Choices Restaurant & Bar
# 91769   WrgdQF8kzvONbZctSPlF4A                           Ichiban
# 92564   um2W1Gi4-zR7e17t5pZ_Pg            Nashville Street Tacos
# 109109  9TvJuG22ZyCXJVYzDaDNxw                          Pita Pit
# 130647  qnOffBt8iV6umLvDZ5PNDw                Music City Chicken
# 136447  k7o9D7XQ0eGuz3nmKB1wXg  McFadden's Restaurant and Saloon
# 148131  NfOnxD8NT4UQmSfBY6iqng                  The George Jones
# 150322  2MAQeAqmD8enCT2ZYqUgIQ       The Melting Pot - Nashville
#
#                      address       city state postal_code   latitude  \
# 1494           139 2nd Ave N  Nashville    TN       37201  36.162919
# 4689           113 2nd Ave N  Nashville    TN       37201  36.162251
# 40375          184 2nd Ave N  Nashville    TN       37201  36.164572
# 55579          135 2nd Ave N  Nashville    TN       37201  36.162812
# 58366          901 2nd Ave N  Nashville    TN       37201  36.157588
# 78237          164 2nd Ave N  Nashville    TN       37201  36.163949
# 81389          128 2nd Ave N  Nashville    TN       37201  36.163090
# 91769          109 2nd Ave N  Nashville    TN       37201  36.162124
# 92564          129 2nd Ave N  Nashville    TN       37201  36.162625
# 109109         121 2nd Ave N  Nashville    TN       37201  36.162500
# 130647         109 2nd Ave N  Nashville    TN       37201  36.162162
# 136447         134 2nd Ave N  Nashville    TN       37201  36.163155
# 148131         128 2nd Ave N  Nashville    TN       37201  36.162983
# 150322  166 2nd Ave N, Ste A  Nashville    TN       37201  36.163875
#
#         longitude  stars  review_count  is_open  \
# 1494   -86.776160    3.0            89        0
# 4689   -86.775710    4.0            75        0
# 40375  -86.776655    2.0           115        0
# 55579  -86.776075    2.0            12        0
# 58366  -86.780780    2.5           122        0
# 78237  -86.775981    4.5            12        0
# 81389  -86.775096    2.5            13        0
# 91769  -86.775627    4.0           144        0
# 92564  -86.775847    3.5           103        0
# 109109 -86.775760    3.0            79        0
# 130647 -86.775591    4.5           132        0
# 136447 -86.775456    2.0            46        0
# 148131 -86.775375    3.5           316        0
# 150322 -86.776311    4.0           204        0
#
#                                                attributes  \
# 1494    {'RestaurantsReservations': 'False', 'Restaura...
# 4689    {'OutdoorSeating': 'False', 'RestaurantsReserv...
# 40375   {'RestaurantsAttire': "u'casual'", 'HasTV': 'T...
# 55579   {'Ambience': "{'romantic': False, 'intimate': ...
# 58366   {'BYOB': 'False', 'GoodForKids': 'False', 'Goo...
# 78237   {'Corkage': 'False', 'RestaurantsTableService'...
# 81389   {'HappyHour': 'True', 'WheelchairAccessible': ...
# 91769   {'NoiseLevel': "u'quiet'", 'OutdoorSeating': '...
# 92564   {'Ambience': "{'romantic': False, 'intimate': ...
# 109109  {'WiFi': "'no'", 'OutdoorSeating': 'False', 'R...
# 130647  {'RestaurantsReservations': 'False', 'OutdoorS...
# 136447  {'Alcohol': "u'full_bar'", 'OutdoorSeating': '...
# 148131  {'BusinessParking': "{'garage': True, 'street'...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
#
#                                                categories  \
# 1494                                 Restaurants, Mexican
# 4689    Restaurants, Dive Bars, Sports Bars, Bars, Nig...
# 40375   American (Traditional), Chicken Wings, Bars, N...
# 55579   Cafes, Restaurants, Nightlife, Bars, Hookah Ba...
# 58366            Steakhouses, Restaurants, Food, Desserts
# 78237   Desserts, French, Breakfast & Brunch, Restaura...
# 81389   Bars, Nightlife, American (Traditional), South...
# 91769                   Sushi Bars, Japanese, Restaurants
# 92564                          Restaurants, Mexican, Food
# 109109  Fast Food, Restaurants, Event Planning & Servi...
# 130647  Restaurants, Food, Sandwiches, Beer, Wine & Sp...
# 136447  Burgers, Pubs, Nightlife, Restaurants, Bars, I...
# 148131  Restaurants, Arts & Entertainment, Bars, Night...
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
#
#                                                     hours
# 1494    {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 4689    {'Monday': '11:0-3:0', 'Tuesday': '11:0-3:0', ...
# 40375   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 55579   {'Monday': '17:0-3:0', 'Tuesday': '17:0-3:0', ...
# 58366   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 78237   {'Tuesday': '10:0-21:0', 'Wednesday': '10:0-21...
# 81389   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 91769   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 92564   {'Monday': '11:0-21:0', 'Tuesday': '11:0-23:0'...
# 109109  {'Monday': '10:0-2:0', 'Tuesday': '10:0-2:0', ...
# 130647  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 136447  {'Monday': '11:0-3:0', 'Tuesday': '11:0-3:0', ...
# 148131  {'Monday': '0:0-0:0', 'Thursday': '11:0-22:0',...
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...

# %% [markdown]
# Now, we are creating a new data frame with restaurants on 2nd Ave that are still open, printed the length of the data frame, and displayed the data frame. This is so that we can compare the characteristics of closed restaurants from the cell above and open restaurants.

# %% [markdown]
# Here, we are narrowing down our restaurant data in Nashville to include only those restaurants where the address contains the fact that the restaurants are on 2nd Ave. To compare the number of restaurants that fit this category and the one in the cell above, we printed out the length of this data frame and then displayed the data frame.

# %%
is_open = two_ave[two_ave["is_open"] == 1]
print(len(is_open))
is_open
# Out:
# 17
#                    business_id                                     name  \
# 89      oaboaRBUgGjbo2kfUIKDLQ                         Mike's Ice Cream
# 159     X_E7U2lVNEwbH_gpOBmAHQ                           Cerveza Jack's
# 7710    xB2NmS0JG1Vgy7dK2ftcwQ                        Taco Bell Cantina
# 17517   maOMGu_2dSHKydBgZdTsvQ                         Wildhorse Saloon
# 26266   xlMQBBt9wrtahdqiRDcVSg                             The Stillery
# 27061   LF8UjsBRaQ4Aqwu3ARxnBg   Rodizio Grill The Brazilian Steakhouse
# 71945   UlrEGYuRd5pxW0n4iCR9CQ                             Chicken Guy!
# 83703   NXaw6ox4vQkLfQ13sq_oGg                    Porch Coffee & Market
# 85574   ZDY-jvetOMOE5BMM8e_BcQ           Dick's Last Resort - Nashville
# 87435   Dp6QT6_evsKemZNKgtJ7nA            REPUBLIC quality food & drink
# 98446   RMt9p9efzYfV_cHwXLB-CA                            Gray & Dudley
# 107768  2VczMMo9tWBNPBEHMnoP5w                      Buffalo's Nashville
# 111448  vpQWbT7ZKcHMVKxEVR8Cuw                    Benchmark Bar & Grill
# 114525  Tdp95AviUqzvUd3H2C5xvw                         Famous Nashville
# 125972  py2JAvs-JwqMgllQ7YtP8A  The Murder Mystery Company in Nashville
# 141909  1KpNlu8VM8ukw3uOzmMFPA                     BB King's Blues Club
# 148956  nygJ4mY0glpdWGv_Hmp6Dg                         Joe's Crab Shack
#
#                      address       city state postal_code   latitude  \
# 89             129 2nd Ave N  Nashville    TN       37201  36.162649
# 159            135 2nd Ave N  Nashville    TN       37201  36.162799
# 7710           131 2nd Ave N  Nashville    TN       37201  36.162724
# 17517          120 2nd Ave N  Nashville    TN       37201  36.162766
# 26266          113 2nd Ave N  Nashville    TN       37201  36.162249
# 27061   166 2nd Ave N, Ste C  Nashville    TN       37201  36.164010
# 71945          139 2nd Ave N  Nashville    TN       37201  36.162919
# 83703          401 2nd Ave S  Nashville    TN       37201  36.157509
# 85574          154 2nd Ave N  Nashville    TN       37201  36.163671
# 87435          109 2nd Ave N  Nashville    TN       37201  36.162162
# 98446          221 2nd Ave N  Nashville    TN       37201  36.165252
# 107768         154 2nd Ave N  Nashville    TN       37201  36.163671
# 111448         117 2nd Ave N  Nashville    TN       37201  36.162408
# 114525         110 2nd Ave N  Nashville    TN       37201  36.162290
# 125972         160 2nd Ave N  Nashville    TN       37201  36.163869
# 141909         152 2nd Ave N  Nashville    TN       37201  36.163424
# 148956         123 2nd Ave S  Nashville    TN       37201  36.160947
#
#         longitude  stars  review_count  is_open  \
# 89     -86.775973    4.5           593        1
# 159    -86.776016    4.0           182        1
# 7710   -86.776014    2.5            26        1
# 17517  -86.775178    3.5           559        1
# 26266  -86.775712    4.5          2588        1
# 27061  -86.776030    4.0           510        1
# 71945  -86.776068    3.0            24        1
# 83703  -86.772627    4.5            14        1
# 85574  -86.775767    3.0           153        1
# 87435  -86.775591    4.0            16        1
# 98446  -86.777809    4.0           181        1
# 107768 -86.775767    3.5            63        1
# 111448 -86.775813    4.0           109        1
# 114525 -86.775283    3.5           109        1
# 125972 -86.775873    1.5             8        1
# 141909 -86.776030    3.5           583        1
# 148956 -86.774865    3.0           192        1
#
#                                                attributes  \
# 89      {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 159     {'GoodForDancing': 'True', 'Smoking': "u'no'",...
# 7710                      {'RestaurantsDelivery': 'True'}
# 17517   {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 26266   {'BikeParking': 'True', 'CoatCheck': 'False', ...
# 27061   {'BikeParking': 'False', 'RestaurantsAttire': ...
# 71945   {'OutdoorSeating': 'True', 'Caters': 'True', '...
# 83703   {'OutdoorSeating': 'True', 'RestaurantsTableSe...
# 85574   {'GoodForKids': 'False', 'RestaurantsGoodForGr...
# 87435   {'WheelchairAccessible': 'True', 'RestaurantsR...
# 98446   {'RestaurantsTableService': 'True', 'Restauran...
# 107768  {'Alcohol': "'full_bar'", 'BikeParking': 'True...
# 111448  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 114525  {'BestNights': "{'monday': False, 'tuesday': F...
# 125972  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 141909  {'RestaurantsTakeOut': 'True', 'Caters': 'True...
# 148956  {'OutdoorSeating': 'True', 'BYOBCorkage': "'no...
#
#                                                categories  \
# 89      Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# 159                 Nightlife, Restaurants, Bars, Mexican
# 7710    Arts & Entertainment, Music Venues, Fast Food,...
# 17517   Tours, Local Flavor, Hotels & Travel, Arts & E...
# 26266   American (New), Restaurants, Pubs, Beer, Wine ...
# 27061    Gluten-Free, Brazilian, Restaurants, Steakhouses
# 71945    Restaurants, Chicken Shop, Fast Food, Sandwiches
# 83703   Convenience Stores, Food, Beer, Wine & Spirits...
# 85574   American (Traditional), Restaurants, Nightlife...
# 87435                             Gastropubs, Restaurants
# 98446               American (New), Restaurants, Southern
# 107768  Bars, Nightlife, Sports Bars, Beer, Wine & Spi...
# 111448  American (New), Restaurants, Bars, Arts & Ente...
# 114525  Music Venues, Lounges, American (Traditional),...
# 125972  Event Planning & Services, Restaurants, Food, ...
# 141909  Music Venues, American (Traditional), Wine Bar...
# 148956  American (Traditional), Seafood, Gluten-Free, ...
#
#                                                     hours
# 89      {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
# 159     {'Monday': '0:0-0:0', 'Wednesday': '11:0-22:0'...
# 7710    {'Monday': '10:0-1:45', 'Tuesday': '10:0-1:45'...
# 17517   {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...
# 26266   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 27061   {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:30',...
# 71945   {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 83703   {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
# 85574   {'Monday': '12:0-20:0', 'Tuesday': '12:0-20:0'...
# 87435   {'Monday': '16:0-0:0', 'Tuesday': '16:0-0:0', ...
# 98446   {'Monday': '0:0-0:0', 'Wednesday': '15:0-22:45...
# 107768  {'Monday': '12:0-23:0', 'Tuesday': '12:0-23:0'...
# 111448  {'Monday': '15:0-23:0', 'Tuesday': '15:0-23:0'...
# 114525  {'Wednesday': '11:0-22:0', 'Thursday': '11:0-2...
# 125972  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
# 141909  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 148956  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...

# %% [markdown]
# Here, we created a function that could find, from the hours column (the timings that restaurants are opened each day) in our data frames. In open_hrs, there is one parameter called biz_hrs which takes in column hours in any of the data frames we created above. Then, we first separated the string in the hours column that is passed in by using the commas to split the string up. After, we used a for loop to find the day of the week from the split up string by looking for the colon and taking a portion of the string that was before this colon. This was set to dayofWeek. Then, we got the open hours by splitting at the dashes. Then, we found the actual open and closed times by hours and minutes and converted the values into integers. We put these variables into a list and checked, with an if statement, whether the closed hours were less than 12 hours. If they were, we added 24 to it so that we could later find the difference between the closed hours and the open hours. The same thing was done with the minutes. Then, we checked whether the minutes found were equal to 60 minutes so that we could just, in that situation, add onto the hours instead. We then created a sum variable that is a list of the hours and minutes. The total hours open were then found by taking summing together the hours and the minutes, and printed this variable (total_hrs) out for reference and returned it in the function. To check whether this function worked, we ran this function with the restaurants in the closed restaurants data frame and the open restaurants data frame.

# %%
def open_hrs(biz_hrs): 
    # separate string by commas
    hrsum = 0;
    minsum = 0;
    hrs = biz_hrs[1:len(biz_hrs)-1].split(", ")
    for day in hrs:
        dayofWeek = day[:day.find(":")]
#         print(dayofWeek)
        open_hrs = day[day.find(": ")+3:].split("-")
    
        # true opening/closing time
        open_hr = int(open_hrs[0][:open_hrs[0].find(":")]) 
        open_min = int(open_hrs[0][open_hrs[0].find(":")+1:])
        closed_hr = int(open_hrs[1][:open_hrs[1].find(":")])
        closed_min = int(open_hrs[1][open_hrs[1].find(":")+1:len(open_hrs[1])-1])
        
        # true operating hours and mins
        open_hrs = [open_hr, closed_hr]
        open_mins = [open_min, closed_min]
        if open_hrs[1] < 12:
            open_hrs[1] += 24
#         print(open_hrs)
#         print(open_mins)
#         print(abs(open_hrs[1] - open_hrs[0]))
#         print(abs(open_mins[1] - open_mins[0]))
#         print()
        hrsum += abs(open_hrs[1] - open_hrs[0])
        minsum += abs(open_mins[1] - open_mins[0])
        if minsum == 60:
            hrsum += 1
            minsum = 0
    sum = [hrsum, minsum]
    total_hrs = sum[0] + sum[1]/60
#     print(sum)
#     print(total_hrs)
#     print()
#     print()
    return total_hrs

# %% [markdown]
# Here, we are checking whether the restaurants on 2nd Ave are still open or not by using the binary column "is_open" that is given in the data. We then selected all the restaurants on 2nd Ave that are closed and created a new data frame with this data. We again printed the length of the new data frame and displayed the contents. We have also displayed the average number of stars of open restaurants and the average total hours of closed restaurants (when they were still operating).

# %%
closed_biz_hrs = pd.DataFrame(is_closed)
closed_total_hrs = []
for biz in is_closed.hours:
    closed_total_hrs.append(open_hrs(biz))
closed_biz_hrs["total_hrs"] = closed_total_hrs
print("Avg stars of closed restaurants: " + str(np.mean(closed_biz_hrs["stars"])))
print("Avg total hours of closed businesses: " + str(np.mean(closed_biz_hrs["total_hrs"])))

# Spearman correlation
print(stats.spearmanr(closed_biz_hrs["total_hrs"], closed_biz_hrs["stars"]))

closed_biz_hrs
# Out:
# Avg stars of closed restaurants: 3.2142857142857144
# Avg total hours of closed businesses: 76.78571428571429
# SpearmanrResult(correlation=-0.15514359133493022, pvalue=0.5963909287409439)
#                    business_id                              name  \
# 1494    8s1uT8dyBEUwTNeHoZntMg                            El Rey
# 4689    QUxFneps0qX5S8XpEUnazg             Piranha's Bar & Grill
# 40375   DaQ6YSXmoXQH1qYXNSR1hA                           Hooters
# 55579   E8nFvonCaW63W9d3zUYhgQ                       Bebo's Cafe
# 58366   JWUkEIayb3F8la3TWe-eyw                         Stockyard
# 78237   VuubVgCDC4rbvF_iPIhh1A                          Bartella
# 81389   cxQ3CKel3EEZLYEyu9v3og          Choices Restaurant & Bar
# 91769   WrgdQF8kzvONbZctSPlF4A                           Ichiban
# 92564   um2W1Gi4-zR7e17t5pZ_Pg            Nashville Street Tacos
# 109109  9TvJuG22ZyCXJVYzDaDNxw                          Pita Pit
# 130647  qnOffBt8iV6umLvDZ5PNDw                Music City Chicken
# 136447  k7o9D7XQ0eGuz3nmKB1wXg  McFadden's Restaurant and Saloon
# 148131  NfOnxD8NT4UQmSfBY6iqng                  The George Jones
# 150322  2MAQeAqmD8enCT2ZYqUgIQ       The Melting Pot - Nashville
#
#                      address       city state postal_code   latitude  \
# 1494           139 2nd Ave N  Nashville    TN       37201  36.162919
# 4689           113 2nd Ave N  Nashville    TN       37201  36.162251
# 40375          184 2nd Ave N  Nashville    TN       37201  36.164572
# 55579          135 2nd Ave N  Nashville    TN       37201  36.162812
# 58366          901 2nd Ave N  Nashville    TN       37201  36.157588
# 78237          164 2nd Ave N  Nashville    TN       37201  36.163949
# 81389          128 2nd Ave N  Nashville    TN       37201  36.163090
# 91769          109 2nd Ave N  Nashville    TN       37201  36.162124
# 92564          129 2nd Ave N  Nashville    TN       37201  36.162625
# 109109         121 2nd Ave N  Nashville    TN       37201  36.162500
# 130647         109 2nd Ave N  Nashville    TN       37201  36.162162
# 136447         134 2nd Ave N  Nashville    TN       37201  36.163155
# 148131         128 2nd Ave N  Nashville    TN       37201  36.162983
# 150322  166 2nd Ave N, Ste A  Nashville    TN       37201  36.163875
#
#         longitude  stars  review_count  is_open  \
# 1494   -86.776160    3.0            89        0
# 4689   -86.775710    4.0            75        0
# 40375  -86.776655    2.0           115        0
# 55579  -86.776075    2.0            12        0
# 58366  -86.780780    2.5           122        0
# 78237  -86.775981    4.5            12        0
# 81389  -86.775096    2.5            13        0
# 91769  -86.775627    4.0           144        0
# 92564  -86.775847    3.5           103        0
# 109109 -86.775760    3.0            79        0
# 130647 -86.775591    4.5           132        0
# 136447 -86.775456    2.0            46        0
# 148131 -86.775375    3.5           316        0
# 150322 -86.776311    4.0           204        0
#
#                                                attributes  \
# 1494    {'RestaurantsReservations': 'False', 'Restaura...
# 4689    {'OutdoorSeating': 'False', 'RestaurantsReserv...
# 40375   {'RestaurantsAttire': "u'casual'", 'HasTV': 'T...
# 55579   {'Ambience': "{'romantic': False, 'intimate': ...
# 58366   {'BYOB': 'False', 'GoodForKids': 'False', 'Goo...
# 78237   {'Corkage': 'False', 'RestaurantsTableService'...
# 81389   {'HappyHour': 'True', 'WheelchairAccessible': ...
# 91769   {'NoiseLevel': "u'quiet'", 'OutdoorSeating': '...
# 92564   {'Ambience': "{'romantic': False, 'intimate': ...
# 109109  {'WiFi': "'no'", 'OutdoorSeating': 'False', 'R...
# 130647  {'RestaurantsReservations': 'False', 'OutdoorS...
# 136447  {'Alcohol': "u'full_bar'", 'OutdoorSeating': '...
# 148131  {'BusinessParking': "{'garage': True, 'street'...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
#
#                                                categories  \
# 1494                                 Restaurants, Mexican
# 4689    Restaurants, Dive Bars, Sports Bars, Bars, Nig...
# 40375   American (Traditional), Chicken Wings, Bars, N...
# 55579   Cafes, Restaurants, Nightlife, Bars, Hookah Ba...
# 58366            Steakhouses, Restaurants, Food, Desserts
# 78237   Desserts, French, Breakfast & Brunch, Restaura...
# 81389   Bars, Nightlife, American (Traditional), South...
# 91769                   Sushi Bars, Japanese, Restaurants
# 92564                          Restaurants, Mexican, Food
# 109109  Fast Food, Restaurants, Event Planning & Servi...
# 130647  Restaurants, Food, Sandwiches, Beer, Wine & Sp...
# 136447  Burgers, Pubs, Nightlife, Restaurants, Bars, I...
# 148131  Restaurants, Arts & Entertainment, Bars, Night...
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
#
#                                                     hours  total_hrs
# 1494    {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       73.0
# 4689    {'Monday': '11:0-3:0', 'Tuesday': '11:0-3:0', ...      112.0
# 40375   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       77.0
# 55579   {'Monday': '17:0-3:0', 'Tuesday': '17:0-3:0', ...       70.0
# 58366   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...       36.0
# 78237   {'Tuesday': '10:0-21:0', 'Wednesday': '10:0-21...       66.0
# 81389   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       77.0
# 91769   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...       33.0
# 92564   {'Monday': '11:0-21:0', 'Tuesday': '11:0-23:0'...       89.0
# 109109  {'Monday': '10:0-2:0', 'Tuesday': '10:0-2:0', ...      110.0
# 130647  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       83.0
# 136447  {'Monday': '11:0-3:0', 'Tuesday': '11:0-3:0', ...      112.0
# 148131  {'Monday': '0:0-0:0', 'Thursday': '11:0-22:0',...       76.0
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...       61.0

# %%
sns.regplot(x=closed_biz_hrs["total_hrs"], y=closed_biz_hrs["stars"])
coeff = np.polyfit(x=closed_biz_hrs["total_hrs"], y=closed_biz_hrs["stars"], deg=1)
print(coeff)
y = coeff[0]*closed_biz_hrs["total_hrs"] + coeff[1]
print("The equation for the line is y = " + str(coeff[0]) + "x + " + str(coeff[1]))
# Out:
# [-0.00435274  3.54851373]
# The equation for the line is y = -0.004352736989999734x + 3.548513733160693

# %% [markdown]
# Now, we are creating a new data frame with restaurants on 2nd Ave that are still open, printed the length of the data frame, and displayed the data frame. This is so that we can compare the characteristics of closed restaurants from the cell above and open restaurants. We have also displayed the average number of stars of open restaurants and the average total hours of open businesses.

# %%
open_biz_hrs = pd.DataFrame(is_open)
open_total_hrs = []
for biz in is_open.hours:
    open_total_hrs.append(open_hrs(biz))
open_biz_hrs["total_hrs"] = open_total_hrs
print("Avg stars of open restaurants: " + str(np.mean(open_biz_hrs["stars"])))
print("Avg total hours of open businesses: " + str(np.mean(open_biz_hrs["total_hrs"])))

# Spearman correlation
print(stats.spearmanr(open_biz_hrs["total_hrs"], open_biz_hrs["stars"]))

open_biz_hrs
# Out:
# Avg stars of open restaurants: 3.5588235294117645
# Avg total hours of open businesses: 74.41176470588235
# SpearmanrResult(correlation=-0.02638865733998216, pvalue=0.9199216567242325)
#                    business_id                                     name  \
# 89      oaboaRBUgGjbo2kfUIKDLQ                         Mike's Ice Cream
# 159     X_E7U2lVNEwbH_gpOBmAHQ                           Cerveza Jack's
# 7710    xB2NmS0JG1Vgy7dK2ftcwQ                        Taco Bell Cantina
# 17517   maOMGu_2dSHKydBgZdTsvQ                         Wildhorse Saloon
# 26266   xlMQBBt9wrtahdqiRDcVSg                             The Stillery
# 27061   LF8UjsBRaQ4Aqwu3ARxnBg   Rodizio Grill The Brazilian Steakhouse
# 71945   UlrEGYuRd5pxW0n4iCR9CQ                             Chicken Guy!
# 83703   NXaw6ox4vQkLfQ13sq_oGg                    Porch Coffee & Market
# 85574   ZDY-jvetOMOE5BMM8e_BcQ           Dick's Last Resort - Nashville
# 87435   Dp6QT6_evsKemZNKgtJ7nA            REPUBLIC quality food & drink
# 98446   RMt9p9efzYfV_cHwXLB-CA                            Gray & Dudley
# 107768  2VczMMo9tWBNPBEHMnoP5w                      Buffalo's Nashville
# 111448  vpQWbT7ZKcHMVKxEVR8Cuw                    Benchmark Bar & Grill
# 114525  Tdp95AviUqzvUd3H2C5xvw                         Famous Nashville
# 125972  py2JAvs-JwqMgllQ7YtP8A  The Murder Mystery Company in Nashville
# 141909  1KpNlu8VM8ukw3uOzmMFPA                     BB King's Blues Club
# 148956  nygJ4mY0glpdWGv_Hmp6Dg                         Joe's Crab Shack
#
#                      address       city state postal_code   latitude  \
# 89             129 2nd Ave N  Nashville    TN       37201  36.162649
# 159            135 2nd Ave N  Nashville    TN       37201  36.162799
# 7710           131 2nd Ave N  Nashville    TN       37201  36.162724
# 17517          120 2nd Ave N  Nashville    TN       37201  36.162766
# 26266          113 2nd Ave N  Nashville    TN       37201  36.162249
# 27061   166 2nd Ave N, Ste C  Nashville    TN       37201  36.164010
# 71945          139 2nd Ave N  Nashville    TN       37201  36.162919
# 83703          401 2nd Ave S  Nashville    TN       37201  36.157509
# 85574          154 2nd Ave N  Nashville    TN       37201  36.163671
# 87435          109 2nd Ave N  Nashville    TN       37201  36.162162
# 98446          221 2nd Ave N  Nashville    TN       37201  36.165252
# 107768         154 2nd Ave N  Nashville    TN       37201  36.163671
# 111448         117 2nd Ave N  Nashville    TN       37201  36.162408
# 114525         110 2nd Ave N  Nashville    TN       37201  36.162290
# 125972         160 2nd Ave N  Nashville    TN       37201  36.163869
# 141909         152 2nd Ave N  Nashville    TN       37201  36.163424
# 148956         123 2nd Ave S  Nashville    TN       37201  36.160947
#
#         longitude  stars  review_count  is_open  \
# 89     -86.775973    4.5           593        1
# 159    -86.776016    4.0           182        1
# 7710   -86.776014    2.5            26        1
# 17517  -86.775178    3.5           559        1
# 26266  -86.775712    4.5          2588        1
# 27061  -86.776030    4.0           510        1
# 71945  -86.776068    3.0            24        1
# 83703  -86.772627    4.5            14        1
# 85574  -86.775767    3.0           153        1
# 87435  -86.775591    4.0            16        1
# 98446  -86.777809    4.0           181        1
# 107768 -86.775767    3.5            63        1
# 111448 -86.775813    4.0           109        1
# 114525 -86.775283    3.5           109        1
# 125972 -86.775873    1.5             8        1
# 141909 -86.776030    3.5           583        1
# 148956 -86.774865    3.0           192        1
#
#                                                attributes  \
# 89      {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 159     {'GoodForDancing': 'True', 'Smoking': "u'no'",...
# 7710                      {'RestaurantsDelivery': 'True'}
# 17517   {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 26266   {'BikeParking': 'True', 'CoatCheck': 'False', ...
# 27061   {'BikeParking': 'False', 'RestaurantsAttire': ...
# 71945   {'OutdoorSeating': 'True', 'Caters': 'True', '...
# 83703   {'OutdoorSeating': 'True', 'RestaurantsTableSe...
# 85574   {'GoodForKids': 'False', 'RestaurantsGoodForGr...
# 87435   {'WheelchairAccessible': 'True', 'RestaurantsR...
# 98446   {'RestaurantsTableService': 'True', 'Restauran...
# 107768  {'Alcohol': "'full_bar'", 'BikeParking': 'True...
# 111448  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 114525  {'BestNights': "{'monday': False, 'tuesday': F...
# 125972  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 141909  {'RestaurantsTakeOut': 'True', 'Caters': 'True...
# 148956  {'OutdoorSeating': 'True', 'BYOBCorkage': "'no...
#
#                                                categories  \
# 89      Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# 159                 Nightlife, Restaurants, Bars, Mexican
# 7710    Arts & Entertainment, Music Venues, Fast Food,...
# 17517   Tours, Local Flavor, Hotels & Travel, Arts & E...
# 26266   American (New), Restaurants, Pubs, Beer, Wine ...
# 27061    Gluten-Free, Brazilian, Restaurants, Steakhouses
# 71945    Restaurants, Chicken Shop, Fast Food, Sandwiches
# 83703   Convenience Stores, Food, Beer, Wine & Spirits...
# 85574   American (Traditional), Restaurants, Nightlife...
# 87435                             Gastropubs, Restaurants
# 98446               American (New), Restaurants, Southern
# 107768  Bars, Nightlife, Sports Bars, Beer, Wine & Spi...
# 111448  American (New), Restaurants, Bars, Arts & Ente...
# 114525  Music Venues, Lounges, American (Traditional),...
# 125972  Event Planning & Services, Restaurants, Food, ...
# 141909  Music Venues, American (Traditional), Wine Bar...
# 148956  American (Traditional), Seafood, Gluten-Free, ...
#
#                                                     hours  total_hrs
# 89      {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...     107.50
# 159     {'Monday': '0:0-0:0', 'Wednesday': '11:0-22:0'...      85.00
# 7710    {'Monday': '10:0-1:45', 'Tuesday': '10:0-1:45'...     112.25
# 17517   {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...      30.00
# 26266   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...      79.00
# 27061   {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:30',...      62.50
# 71945   {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...      91.00
# 83703   {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...      61.50
# 85574   {'Monday': '12:0-20:0', 'Tuesday': '12:0-20:0'...      60.00
# 87435   {'Monday': '16:0-0:0', 'Tuesday': '16:0-0:0', ...      56.00
# 98446   {'Monday': '0:0-0:0', 'Wednesday': '15:0-22:45...      74.75
# 107768  {'Monday': '12:0-23:0', 'Tuesday': '12:0-23:0'...      79.00
# 111448  {'Monday': '15:0-23:0', 'Tuesday': '15:0-23:0'...      78.00
# 114525  {'Wednesday': '11:0-22:0', 'Thursday': '11:0-2...      61.50
# 125972  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...      72.00
# 141909  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...      87.00
# 148956  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...      68.00

# %%
sns.regplot(x=open_biz_hrs["total_hrs"], y=open_biz_hrs["stars"])
coeff = np.polyfit(x=open_biz_hrs["total_hrs"], y=open_biz_hrs["stars"], deg=1)
print(coeff)
y = coeff[0]*open_biz_hrs["total_hrs"] + coeff[1]
print("The equation for the line is y = " + str(coeff[0]) + "x + " + str(coeff[1]))
# Out:
# [-2.27546609e-03  3.72814498e+00]
# The equation for the line is y = -0.002275466089118631x + 3.728144976631475

# %% [markdown]
# Findings:
#  - On both plots, the slope comparing total hours of a restaurant per week and stars of restaurants on 2nd Ave is very small.  There's a lot of scatter among the points, which suggests that the stars and total hours open per week are not correlated.
#  - Upon running a Spearman correlation, we discovered there's basically no correlation between total hours and star ratings.

# %%
with open('./project_files/yelp_academic_dataset_tip.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile, lines=True)
df.to_csv('./project_files/yelp_academic_dataset_tip.csv', encoding='utf-8', index = False)

# %%
tip_data = pd.read_csv('./project_files/yelp_academic_dataset_tip.csv')
tip_data = tip_data.rename(columns={'text': 'tip_text'})
tip_data
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                  tip_text  \
# 0                          Avengers time with the ladies.
# 1       They have lots of good deserts and tasty cuban...
# 2                  It's open even when you think it isn't
# 3                               Very decent fried chicken
# 4                  Appetizers.. platter special for lunch
# ...                                                   ...
# 908910              Disappointed in one of your managers.
# 908911                            Great food and service.
# 908912                                Love their Cubans!!
# 908913                            Great pizza great price
# 908914                  Food is good value but a bit hot!
#
#                        date  compliment_count
# 0       2012-05-18 02:17:21                 0
# 1       2013-02-05 18:35:10                 0
# 2       2013-08-18 00:56:08                 0
# 3       2017-06-27 23:05:38                 0
# 4       2012-10-06 19:43:09                 0
# ...                     ...               ...
# 908910  2021-09-11 19:18:57                 0
# 908911  2021-10-30 11:54:36                 0
# 908912  2021-11-05 13:18:56                 0
# 908913  2021-11-20 16:11:44                 0
# 908914  2021-12-07 22:30:00                 0
#
# [908915 rows x 5 columns]

# %%
review_res = pd.merge(tip_data, two_ave, on="business_id", how="inner")
review_res
# Out:
#                     user_id             business_id  \
# 0    _9e1YCM0JVFDDAeqaL5fjA  maOMGu_2dSHKydBgZdTsvQ
# 1    Y4Uoo78j_j8GJU-5AjgxZQ  maOMGu_2dSHKydBgZdTsvQ
# 2    afJr0bfIXMJdbHO_Nk_bNA  maOMGu_2dSHKydBgZdTsvQ
# 3    0X8qZFI5YDJmQyVSrLkmWQ  maOMGu_2dSHKydBgZdTsvQ
# 4    4XEO4b2mO7U35LzxiSIkqw  maOMGu_2dSHKydBgZdTsvQ
# ..                      ...                     ...
# 733  j0abxKWiEt_tmcUPDpd29g  qnOffBt8iV6umLvDZ5PNDw
# 734  ym_hf04KKL8uBq3Oa3Xzkg  qnOffBt8iV6umLvDZ5PNDw
# 735  4TSWcklvALG8huJgT_zwAQ  qnOffBt8iV6umLvDZ5PNDw
# 736  KcaCrCKQycq6TqMcT8LTNg  UlrEGYuRd5pxW0n4iCR9CQ
# 737  ML7Lpf96HAMATolfZxiuNQ  NXaw6ox4vQkLfQ13sq_oGg
#
#                                               tip_text                 date  \
# 0    Joni, Josiah and Meggan at the 2nd floor bar a...  2013-06-07 22:24:20
# 1    Luke Bryan, Darius Rucker, Sam Bush and some f...  2013-06-04 02:04:49
# 2                         Not a bad seat in the house.  2016-07-29 16:47:06
# 3                       Out for a little Country Music  2011-05-03 01:58:54
# 4             Dealer training is going amazingly well!  2012-02-24 01:18:18
# ..                                                 ...                  ...
# 733  Hot chicken with waffle was great! Washed it d...  2019-09-10 18:47:12
# 734                  Love the chicken and portion size  2019-12-06 05:28:07
# 735  Awesome food! Had the Chicken and Waffle with ...  2019-11-02 16:53:09
# 736  so yummy. Confused as to why this has such a l...  2021-09-04 07:07:53
# 737  Nice quiet place to get a drink and talk befor...  2019-08-03 00:49:43
#
#      compliment_count                   name        address       city state  \
# 0                   0       Wildhorse Saloon  120 2nd Ave N  Nashville    TN
# 1                   0       Wildhorse Saloon  120 2nd Ave N  Nashville    TN
# 2                   0       Wildhorse Saloon  120 2nd Ave N  Nashville    TN
# 3                   0       Wildhorse Saloon  120 2nd Ave N  Nashville    TN
# 4                   0       Wildhorse Saloon  120 2nd Ave N  Nashville    TN
# ..                ...                    ...            ...        ...   ...
# 733                 0     Music City Chicken  109 2nd Ave N  Nashville    TN
# 734                 0     Music City Chicken  109 2nd Ave N  Nashville    TN
# 735                 0     Music City Chicken  109 2nd Ave N  Nashville    TN
# 736                 0           Chicken Guy!  139 2nd Ave N  Nashville    TN
# 737                 0  Porch Coffee & Market  401 2nd Ave S  Nashville    TN
#
#     postal_code   latitude  longitude  stars  review_count  is_open  \
# 0         37201  36.162766 -86.775178    3.5           559        1
# 1         37201  36.162766 -86.775178    3.5           559        1
# 2         37201  36.162766 -86.775178    3.5           559        1
# 3         37201  36.162766 -86.775178    3.5           559        1
# 4         37201  36.162766 -86.775178    3.5           559        1
# ..          ...        ...        ...    ...           ...      ...
# 733       37201  36.162162 -86.775591    4.5           132        0
# 734       37201  36.162162 -86.775591    4.5           132        0
# 735       37201  36.162162 -86.775591    4.5           132        0
# 736       37201  36.162919 -86.776068    3.0            24        1
# 737       37201  36.157509 -86.772627    4.5            14        1
#
#                                             attributes  \
# 0    {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 1    {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 2    {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 3    {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 4    {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# ..                                                 ...
# 733  {'RestaurantsReservations': 'False', 'OutdoorS...
# 734  {'RestaurantsReservations': 'False', 'OutdoorS...
# 735  {'RestaurantsReservations': 'False', 'OutdoorS...
# 736  {'OutdoorSeating': 'True', 'Caters': 'True', '...
# 737  {'OutdoorSeating': 'True', 'RestaurantsTableSe...
#
#                                             categories  \
# 0    Tours, Local Flavor, Hotels & Travel, Arts & E...
# 1    Tours, Local Flavor, Hotels & Travel, Arts & E...
# 2    Tours, Local Flavor, Hotels & Travel, Arts & E...
# 3    Tours, Local Flavor, Hotels & Travel, Arts & E...
# 4    Tours, Local Flavor, Hotels & Travel, Arts & E...
# ..                                                 ...
# 733  Restaurants, Food, Sandwiches, Beer, Wine & Sp...
# 734  Restaurants, Food, Sandwiches, Beer, Wine & Sp...
# 735  Restaurants, Food, Sandwiches, Beer, Wine & Sp...
# 736   Restaurants, Chicken Shop, Fast Food, Sandwiches
# 737  Convenience Stores, Food, Beer, Wine & Spirits...
#
#                                                  hours
# 0    {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...
# 1    {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...
# 2    {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...
# 3    {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...
# 4    {'Thursday': '16:0-22:0', 'Friday': '12:0-0:0'...
# ..                                                 ...
# 733  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 734  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 735  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 736  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 737  {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
#
# [738 rows x 18 columns]
